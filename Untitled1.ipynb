# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
r1=float(input("r1:"))
r2=float(input("r2:"))
S1=3.14*r1*r1
S2=3.14*r2*r2
S=S1-S2
print(S)
# Out:
# r1:5
# r2:7
# -75.36000000000001

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x= int(input("->"))
y = int(input("->"))
z=(x+y)%2==1
print(z)
# Out:
# ->2
# ->3
# True
